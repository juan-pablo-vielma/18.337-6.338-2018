# %%
using JuMP, PolyJuMP, MultivariatePolynomials, DynamicPolynomials, SumOfSquares

type Box
    xl::Float64
    xu::Float64
    yl::Float64
    yu::Float64
end

function solveModel(npieces,degree,boxes::Array{Box},domain::Box,startcondition,endcondition,misdpsolver,tol_int = 1e-9, tol_feas = 1e-9, tol_gap = 1e-6)

    model = SOSModel(solver=misdpsolver)

    tol_nonneg = tol_feas # Tolerance for polynomial nonnegativity

    (X₀, X₀′, X₀′′) = startcondition
    (X₁, X₁′, X₁′′) = endcondition

    # Discretize time into npieces+1 times
    Tmin = 0.
    Tmax = 1.
    T = linspace(Tmin, Tmax, npieces+1)

    # Polynomials are a function of t
    @polyvar(t)
    Z = monomials(t, 0:degree)

    # Binary variables to choose safe regions
    # variables are indexed by trajectory piece (integer 1:npieces) and boxes (of type Box)
    @variable(model, H[1:npieces,boxes], Bin)

    # Big-M values
    (Mxl, Mxu, Myl, Myu) = (domain.xl, domain.xu, domain.yl, domain.yu)
    p = Dict()
    for j in 1:npieces
        @constraint(model, sum(H[j,box] for box in boxes) == 1)

        # Polynomial variables = a variable for the coefficients of each monomial in Z
        p[(:x,j)] = @variable(model, _, PolyJuMP.Poly(Z), basename="px$j")
        p[(:y,j)] = @variable(model, _, PolyJuMP.Poly(Z), basename="py$j")

        # Constraints to choose safe region
        for box in boxes
            xl, xu, yl, yu = box.xl, box.xu, box.yl, box.yu
            @assert xl >= Mxl
            @constraint(model, p[(:x,j)] >= Mxl + (xl-Mxl)*H[j,box], domain = (@set t >= T[j] && t <= T[j+1]))
            @assert xu <= Mxu
            @constraint(model, p[(:x,j)] <= Mxu + (xu-Mxu)*H[j,box], domain = (@set t >= T[j] && t <= T[j+1]))
            @assert yl >= Myl
            @constraint(model, p[(:y,j)] >= Myl + (yl-Myl)*H[j,box], domain = (@set t >= T[j] && t <= T[j+1]))
            @assert yu <= Myu
            @constraint(model, p[(:y,j)] <= Myu + (yu-Myu)*H[j,box], domain = (@set t >= T[j] && t <= T[j+1]))
        end
    end

    # Boundary and interstitial smoothing conditions
    for axis in (:x,:y)
        @constraint(model,               p[(axis,1)       ](t=>Tmin) == X₀[axis])
        @constraint(model, differentiate(p[(axis,1)], t   )(t=>Tmin) == X₀′[axis])
        @constraint(model, differentiate(p[(axis,1)], t, 2)(t=>Tmin) == X₀′′[axis])

        for j in 1:npieces-1
            @constraint(model,               p[(axis,j)       ](t=>T[j+1]) ==               p[(axis,j+1)       ](t=>T[j+1]))
            @constraint(model, differentiate(p[(axis,j)], t   )(t=>T[j+1]) == differentiate(p[(axis,j+1)], t   )(t=>T[j+1]))
            @constraint(model, differentiate(p[(axis,j)], t, 2)(t=>T[j+1]) == differentiate(p[(axis,j+1)], t, 2)(t=>T[j+1]))
        end

        @constraint(model, p[(axis,npieces)](t=>Tmax) == X₁[axis])
    end

    # Objective function
    @variable(model, γ[keys(p)] ≥ 0)
    for (key,val) in p
        @constraint(model, γ[key] ≥ norm(differentiate(val, t, 3)))
    end
    @objective(model, Min, sum(γ))

    solve(model)

    # create and return a function that evaluates the piecewise polynomial anwer
    PP = Dict(key => getvalue(p[key]) for key in keys(p))
    HH = getvalue(H)
    function eval_poly(r)
        for i in 1:npieces
            if T[i] <= r <= T[i+1]
                return PP[(:x,i)](t=>r), PP[(:y,i)](t=>r)
                break
            end
        end
        error("Time $r out of interval [$(minimum(T)),$(maximum(T))]")
    end
end
# Out:
# solveModel (generic function with 4 methods)

# %%
# Define instance
npieces = 8 # Number of trajectory pieces
degree = 3 # degree of polynomial trajectories
boxes = Box[
    Box(0.0,1.0,0.0,0.3),
    Box(0.8,1.7,0.1,0.3),
    Box(1.4,1.9,0.2,0.4),
    Box(1.0,1.7,0.3,0.5),
    Box(0.5,1.4,0.4,0.6),
    Box(0.0,1.0,0.5,0.7),
    Box(0.2,1.0,0.6,0.8),
    Box(0.5,1.3,0.7,0.9),
    Box(1.0,2.0,0.7,1.0),
    ]
domain = Box(0,2,0,1)
# Start location, velocity and acceleration
X₀   = Dict(:x=>0, :y=>0)
X₀′  = Dict(:x=>1, :y=>0)
X₀′′ = Dict(:x=>0, :y=>0)
# End location, velocity and acceleration
X₁   = Dict(:x=>2, :y=>1)
X₁′  = Dict(:x=>1, :y=>0)
X₁′′ = Dict(:x=>0, :y=>0)

# Setup Pajarito MISDP solver
using Pajarito, CPLEX, Mosek
MIPsolver = CplexSolver()
SDPsolver = MosekSolver(MSK_IPAR_LOG=0,MSK_DPAR_INTPNT_CO_TOL_PFEAS=1e-6,MSK_DPAR_INTPNT_CO_TOL_DFEAS=1e-6,
    MSK_DPAR_INTPNT_CO_TOL_REL_GAP=1e-5,MSK_DPAR_INTPNT_TOL_INFEAS=1e-8,MSK_DPAR_INTPNT_CO_TOL_MU_RED=1e-6)
misdpsolver = PajaritoSolver(mip_solver=MIPsolver, mip_subopt_solver=MIPsolver, cont_solver=SDPsolver, mip_solver_drives=true, cut_zero_tol=1e-6, log_level=3, rel_gap=1e-3, solve_relax=false)

# Solve
eval_poly = solveModel(npieces,degree,boxes,domain,(X₀, X₀′, X₀′′),(X₁, X₁′, X₁′′),misdpsolver)
# Out:
# Problem dimensions:
#        variables |    2744
#      constraints |    1314
#    nonzeros in A |    6054
#
# Cones summary:
# Cone             | Count   | Min dim.  | Max dim.
#     Second order |      16 |         2 |         2
#    Pos. semidef. |     864 |       2^2 |       2^2
#
# Variable types:
#       continuous |    2672
#           binary |      72
#
# Transforming data...               0.52s
#
# Creating conic subproblem...       1.32s
#
# Building MIP model...              0.74s
#
# Starting MIP-solver-driven algorithm
# Warning: Control callbacks may disable some MIP features.
# Warning:  Non-integral bounds for integer variables rounded.
# Tried aggregator 2 times.
# MIP Presolve eliminated 1903 rows and 51 columns.
# MIP Presolve modified 194 coefficients.
# Aggregator did 578 substitutions.
# Reduced MIP has 2353 rows, 2131 columns, and 12004 nonzeros.
# Reduced MIP has 63 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (5.46 ticks)
# Probing time = 0.00 sec. (0.17 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 2353 rows, 2131 columns, and 12004 nonzeros.
# Reduced MIP has 63 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (2.31 ticks)
# Probing time = 0.00 sec. (0.17 ticks)
# Clique table members: 7.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.03 sec. (55.51 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
#       0     0       36.6119    20                     36.6119     1031
#       0     2       36.6119    10                     36.6119     1031
# Elapsed time = 10.33 sec. (1779.53 ticks, tree = 0.01 MB, solutions = 0)
#      10    12       36.6119    14                     36.6119     1088
#      11    13       36.6119    13                     36.6119     1093
#      12    14       36.6119    12                     36.6119     1094
#      13    15       36.6119    11                     36.6119     1097
#      14    16       36.9578     9                     36.6119     1123
#      15    17       36.6119    12                     36.6119     1130
#      16    18       36.6119    12                     36.6119     1140
#      17    19       36.6119    11                     36.6119     1142
#      18    20       47.1698     8                     36.6119     1214
#      20    22       47.1698     7                     36.6119     2282
# Elapsed time = 15.93 sec. (2797.42 ticks, tree = 0.03 MB, solutions = 0)
#      40    28      571.3221    11                     36.6119    10849
#      41    29      571.3221    10                     36.6119    10851
#      42    30      571.3221     8                     36.6119    10853
#      43    31      571.3221     9                     36.6119    10863
#      44    32      571.3221     9                     36.6119    10865
#      45    33      571.3221    10                     36.6119    10910
#      46    34      571.3221     9                     36.6119    10914
#      47    35      571.3221     8                     36.6119    10950
#      48    34    infeasible                           36.6119    11762
#      49    35      576.1739     7                     36.6119    11907
# Elapsed time = 24.06 sec. (3883.21 ticks, tree = 0.09 MB, solutions = 0)
#     100    69     9435.6499    14                     36.6119    23686
#     101    70     9435.6499    14                     36.6119    23686
#     102    71     9435.6499    14                     36.6119    23688
#     103    72     9435.6499    14                     36.6119    23690
#     104    73     9435.6499    13                     36.6119    23693
#     105    74     9435.6499    12                     36.6119    23695
#     106    75     9435.6499    11                     36.6119    23696
#     107    76     9435.6499    10                     36.6119    23697
#     108    77     9435.6499     9                     36.6119    23703
#     109    78     9435.6499    10                     36.6119    23707
# Elapsed time = 36.17 sec. (4910.68 ticks, tree = 0.14 MB, solutions = 0)
#     181   126    infeasible                           36.9578    40026
#     182   125    infeasible                           36.9578    40728
#     183   124    infeasible                           47.1698    45430
#     184   125       47.1698     5                     47.1698    45590
#     185   126      490.3867     3                     47.1698    47166
#     186   127      490.9321     2                     47.1698    47198
#     187   128     1533.9452     7                     47.1698    47517
#     188   129     1533.9452     8                     47.1698    47523
#     189   130     1533.9452     7                     47.1698    47526
#     190   131     1533.9452     8                     47.1698    47528
# Elapsed time = 43.72 sec. (6416.60 ticks, tree = 0.21 MB, solutions = 0)
# *   267+  148                         2213.2483       82.9086            96.25%
#     300   175     1731.9902     5     2213.2483       86.4030    62902   96.10%
#     301   176     1731.9902     4     2213.2483       86.4030    62903   96.10%
#     302   177     1731.9902     3     2213.2483       86.4030    62909   96.10%
#     303   178     1731.9902     2     2213.2483       86.4030    62910   96.10%
#     304   177        cutoff           2213.2483       86.4030    62918   96.10%
#     305   176        cutoff           2213.2483       86.4030    62930   96.10%
#     306   175        cutoff           2213.2483       91.2658    64164   95.88%
#     307   176      186.6987     5     2213.2483       92.7055    64902   95.81%
#     308   177      215.8811     8     2213.2483       92.7055    65211   95.81%
#     309   178      743.9610     7     2213.2483       92.7055    65981   95.81%
# Elapsed time = 52.55 sec. (7484.43 ticks, tree = 0.23 MB, solutions = 0)
# *   311+  104                          785.6099       92.7055            88.20%
#     357   125      431.7515     7      785.6099       92.7055    76647   88.20%
#     358   124        cutoff            785.6099       92.7055    77043   88.20%
#     359   125      104.6329     5      785.6099       95.5001    77702   87.84%
#     360   126      134.5093    10      785.6099       95.5001    78105   87.84%
#     361   127      134.5093     9      785.6099       95.5001    78106   87.84%
#     362   128      134.5093     8      785.6099       95.5001    78111   87.84%
#     363   129      134.5093     7      785.6099       95.5001    78116   87.84%
#     364   130      134.5093     8      785.6099       95.5001    78124   87.84%
#     365   131      134.5093     6      785.6099       95.5001    78126   87.84%
#     366   132      134.5093     6      785.6099       95.5001    78131   87.84%
# Elapsed time = 54.88 sec. (8541.76 ticks, tree = 0.19 MB, solutions = 0)
#     446   183        cutoff            785.6099      118.6695    93393   84.89%
#     447   182    infeasible            785.6099      122.8108    93393   84.37%
#     448   181        cutoff            785.6099      122.8108    94080   84.37%
#     449   182      314.7738     8      785.6099      122.8108    95133   84.37%
#     450   183      314.7738     7      785.6099      122.8108    95154   84.37%
#     451   184      314.7738     7      785.6099      122.8108    95155   84.37%
#     452   185      314.7738     6      785.6099      122.8108    95160   84.37%
#     453   186      314.7738     5      785.6099      122.8108    95168   84.37%
#     454   187      314.7738     5      785.6099      122.8108    95190   84.37%
#     455   187      384.3380     2      785.6099      122.8108    95594   84.37%
# Elapsed time = 55.51 sec. (9674.23 ticks, tree = 0.29 MB, solutions = 0)
#     524   194        cutoff            785.6099      134.5093   111667   82.88%
#     525   193        cutoff            785.6099      134.5093   112508   82.88%
#     526   194      610.9332     5      785.6099      134.5093   113326   82.88%
#     527   195      610.9332     5      785.6099      134.5093   113327   82.88%
#     528   196      610.9332     6      785.6099      134.5093   113336   82.88%
#     529   197      610.9332     6      785.6099      134.5093   113351   82.88%
#     530   196        cutoff            785.6099      134.5093   113355   82.88%
#     531   197      610.9332     5      785.6099      134.5093   113371   82.88%
#     532   198      610.9332     4      785.6099      134.5093   113378   82.88%
#     533   197        cutoff            785.6099      134.5093   113384   82.88%
# Elapsed time = 59.11 sec. (10745.04 ticks, tree = 0.31 MB, solutions = 0)
#     623   233        cutoff            785.6099      143.9685   130519   81.67%
#     624   232    infeasible            785.6099      150.4501   130519   80.85%
#     625   231        cutoff            785.6099      151.4493   131206   80.72%
#     626   232      216.1402    12      785.6099      155.1258   132382   80.25%
#     627   233      216.1402    11      785.6099      155.1258   132384   80.25%
#     628   234      216.1402    10      785.6099      155.1258   132387   80.25%
#     629   235      216.1402     9      785.6099      155.1258   132388   80.25%
#     630   236      216.1402     8      785.6099      155.1258   132401   80.25%
#     631   235        cutoff            785.6099      155.1258   132728   80.25%
#     632   236      216.1402     8      785.6099      155.1258   132739   80.25%
# Elapsed time = 59.72 sec. (11829.83 ticks, tree = 0.39 MB, solutions = 0)
#     728   277      707.9419     2      785.6099      169.1842   149317   78.46%
#     729   276        cutoff            785.6099      169.1842   149322   78.46%
#     730   275        cutoff            785.6099      169.1842   149327   78.46%
#     731   274        cutoff            785.6099      169.1842   149741   78.46%
#     732   275      200.0758     8      785.6099      169.1842   150719   78.46%
#     733   276      200.0758     7      785.6099      169.1842   150728   78.46%
#     734   277      200.0758     7      785.6099      169.1842   150746   78.46%
#     735   278      200.0758     6      785.6099      169.1842   150755   78.46%
#     736   279      200.0758     6      785.6099      169.1842   150760   78.46%
# *  1219+   10                          768.4686      731.0352             4.87%
# *  1223    10      integral     0      767.8732      738.3161   198900    3.85%
#    1223    10      767.8732     0      767.8732      738.3161   198900    3.85%
# Elapsed time = 70.28 sec. (16459.19 ticks, tree = 0.03 MB, solutions = 1)
# MIP-solver-driven algorithm summary:
#  - Status               =        Optimal
#  - Best feasible        =  +7.678575e+02
#  - Best bound           =  +7.678732e+02
#  - Relative opt. gap    =     -2.034e-05
#  - Total time (s)       =       7.37e+01
#
# Timers (s):
#  - Setup                =   2.57e+00
#  -- Transform data      =   5.20e-01
#  -- Create conic data   =   1.32e+00
#  -- Create MIP data     =   7.35e-01
#  - Algorithm            =   7.11e+01
#  -- Solve relaxation    =   0.00e+00
#  -- Get relaxation cuts =   0.00e+00
#  -- MIP solver driving  =   7.11e+01
#  -- Solve subproblems   =   5.90e+01
#  -- Get subproblem cuts =   1.43e+00
#  -- Get separation cuts =   2.84e-01
#
# Counters:
#  - Lazy callbacks       =   135
#  -- Integer repeats     =    94
#  -- Conic subproblems   =    41
#  --- Infeasible         =    34
#  --- Optimal            =     7
#  --- Suboptimal         =     0
#  --- UserLimit          =     0
#  --- ConicFailure       =     0
#  --- Other status       =     0
#  -- Feasible solutions  =    12
#  --- From subproblems   =     7
#  --- In lazy callback   =     5
#  - Heuristic callbacks  =   688
#  -- Solutions passed    =     3
#
# Solution returned by conic solver
#
# Rounds of full separation/subproblem cuts, and count of cuts added:
# Cone             | Subp.  | Sep.   | Total  | Relax. | Viol.
#    Pos. semidef. |  50949 |   8042 |  11301 |      0 |  11301
#
# 0 numerically unstable disaggregated SOC cuts
#
# Distance to feasibility (negative indicates strict feasibility):
# Cone             | Variable  | Constraint
#           Linear |  0.00e+00 |  1.25e-06
#     Second order |        NA | -9.92e-06
#    Pos. semidef. |  1.67e-06 |        NA
#
# Distance to integrality of integer/binary variables:
#           binary |  0.00e+00
#
#
# Cover cuts applied:  1
# User cuts applied:  11259
#
# Root node processing (before b&c):
#   Real time             =   10.33 sec. (1779.61 ticks)
# Sequential b&c:
#   Real time             =   59.97 sec. (14728.22 ticks)
#                           ------------
# Total (root+branch&cut) =   70.30 sec. (16507.83 ticks)
# eval_poly (generic function with 1 method)

# %%
eval_poly(0.4)
# Out:
# (0.8582206347987684, 0.17322223109816023)

# %%
using Plots
plot(Shape([domain.xl,domain.xu,domain.xu,domain.xl],[domain.yl,domain.yl,domain.yu,domain.yu]),c = RGB(0,0,1),linewidth = 0,label="")
for box in boxes
    plot!(Shape([box.xl,box.xu,box.xu,box.xl],[box.yl,box.yl,box.yu,box.yu]),c = RGB(1,1,1),linewidth = 0,label="")
end
for t in linspace(0, 1, 100)
    (x,y) = eval_poly(t)
    plot!([x],[y],marker=(:circle ,3, RGB(1,0,0)),label="")
end
plot!()
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip7300">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7300)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip7301">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7300)" points="
# 39.1651,375.869 580.315,375.869 580.315,11.811 39.1651,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip7302">
#     <rect x="39" y="11" width="542" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip7302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   54.4806,375.869 54.4806,11.811
#   "/>
# <polyline clip-path="url(#clip7302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   182.11,375.869 182.11,11.811
#   "/>
# <polyline clip-path="url(#clip7302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   309.74,375.869 309.74,11.811
#   "/>
# <polyline clip-path="url(#clip7302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   437.37,375.869 437.37,11.811
#   "/>
# <polyline clip-path="url(#clip7302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   564.999,375.869 564.999,11.811
#   "/>
# <polyline clip-path="url(#clip7302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.1651,365.565 580.315,365.565
#   "/>
# <polyline clip-path="url(#clip7302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.1651,279.703 580.315,279.703
#   "/>
# <polyline clip-path="url(#clip7302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.1651,193.84 580.315,193.84
#   "/>
# <polyline clip-path="url(#clip7302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.1651,107.977 580.315,107.977
#   "/>
# <polyline clip-path="url(#clip7302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.1651,22.1145 580.315,22.1145
#   "/>
# <polyline clip-path="url(#clip7300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1651,375.869 580.315,375.869
#   "/>
# <polyline clip-path="url(#clip7300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1651,375.869 39.1651,11.811
#   "/>
# <polyline clip-path="url(#clip7300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.4806,375.869 54.4806,370.408
#   "/>
# <polyline clip-path="url(#clip7300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   182.11,375.869 182.11,370.408
#   "/>
# <polyline clip-path="url(#clip7300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   309.74,375.869 309.74,370.408
#   "/>
# <polyline clip-path="url(#clip7300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   437.37,375.869 437.37,370.408
#   "/>
# <polyline clip-path="url(#clip7300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   564.999,375.869 564.999,370.408
#   "/>
# <polyline clip-path="url(#clip7300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1651,365.565 47.2823,365.565
#   "/>
# <polyline clip-path="url(#clip7300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1651,279.703 47.2823,279.703
#   "/>
# <polyline clip-path="url(#clip7300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1651,193.84 47.2823,193.84
#   "/>
# <polyline clip-path="url(#clip7300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1651,107.977 47.2823,107.977
#   "/>
# <polyline clip-path="url(#clip7300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1651,22.1145 47.2823,22.1145
#   "/>
# <g clip-path="url(#clip7300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 54.4806, 389.669)" x="54.4806" y="389.669">0.0</text>
# </g>
# <g clip-path="url(#clip7300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 182.11, 389.669)" x="182.11" y="389.669">0.5</text>
# </g>
# <g clip-path="url(#clip7300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 309.74, 389.669)" x="309.74" y="389.669">1.0</text>
# </g>
# <g clip-path="url(#clip7300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 437.37, 389.669)" x="437.37" y="389.669">1.5</text>
# </g>
# <g clip-path="url(#clip7300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 564.999, 389.669)" x="564.999" y="389.669">2.0</text>
# </g>
# <g clip-path="url(#clip7300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.1651, 370.065)" x="33.1651" y="370.065">0.00</text>
# </g>
# <g clip-path="url(#clip7300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.1651, 284.203)" x="33.1651" y="284.203">0.25</text>
# </g>
# <g clip-path="url(#clip7300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.1651, 198.34)" x="33.1651" y="198.34">0.50</text>
# </g>
# <g clip-path="url(#clip7300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.1651, 112.477)" x="33.1651" y="112.477">0.75</text>
# </g>
# <g clip-path="url(#clip7300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.1651, 26.6145)" x="33.1651" y="26.6145">1.00</text>
# </g>
# <polygon clip-path="url(#clip7302)" points="
# 54.4806,365.565 564.999,365.565 564.999,22.1145 54.4806,22.1145 54.4806,365.565
#   " fill="#0000ff" fill-opacity="1"/>
# <polyline clip-path="url(#clip7302)" style="stroke:#000000; stroke-width:0; stroke-opacity:1; fill:none" points="
#   54.4806,365.565 564.999,365.565 564.999,22.1145 54.4806,22.1145 54.4806,365.565
#   "/>
# <polygon clip-path="url(#clip7302)" points="
# 54.4806,365.565 309.74,365.565 309.74,262.53 54.4806,262.53 54.4806,365.565
#   " fill="#ffffff" fill-opacity="1"/>
# <polyline clip-path="url(#clip7302)" style="stroke:#000000; stroke-width:0; stroke-opacity:1; fill:none" points="
#   54.4806,365.565 309.74,365.565 309.74,262.53 54.4806,262.53 54.4806,365.565
#   "/>
# <polygon clip-path="url(#clip7302)" points="
# 258.688,331.22 488.422,331.22 488.422,262.53 258.688,262.53 258.688,331.22
#   " fill="#ffffff" fill-opacity="1"/>
# <polyline clip-path="url(#clip7302)" style="stroke:#000000; stroke-width:0; stroke-opacity:1; fill:none" points="
#   258.688,331.22 488.422,331.22 488.422,262.53 258.688,262.53 258.688,331.22
#   "/>
# <polygon clip-path="url(#clip7302)" points="
# 411.844,296.875 539.473,296.875 539.473,228.185 411.844,228.185 411.844,296.875
#   " fill="#ffffff" fill-opacity="1"/>
# <polyline clip-path="url(#clip7302)" style="stroke:#000000; stroke-width:0; stroke-opacity:1; fill:none" points="
#   411.844,296.875 539.473,296.875 539.473,228.

# %%
pyplot()
animation = @animate for t in linspace(0, 1, 100)
    plot(Shape([domain.xl,domain.xu,domain.xu,domain.xl],[domain.yl,domain.yl,domain.yu,domain.yu]),c = RGB(0,0,1),linewidth = 0,label="")
    for box in boxes
        plot!(Shape([box.xl,box.xu,box.xu,box.xl],[box.yl,box.yl,box.yu,box.yu]),c = RGB(1,1,1),linewidth = 0,label="")
    end
 
    (x,y) = eval_poly(t)
    plot!([x],[y],marker=(:circle ,3, RGB(1,0,0)),label="")
end
gif(animation,fps=25)
# Out:
# INFO: Saved animation to tmp.gif
# Plots.AnimatedGif("tmp.gif")
